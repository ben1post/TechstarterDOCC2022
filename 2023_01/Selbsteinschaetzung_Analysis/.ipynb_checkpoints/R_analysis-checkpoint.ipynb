# %% [markdown]
# # This is the R analysis

# %%
# load tidyverse suite of packages for data wrangling
library(tidyverse)
library(cowplot)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.0
# ✔ readr   2.1.3      ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# read data
data <- read.csv("selbsteinschaetzung.csv")

# %%
# view data
head(data)
# Out:
#   Zeitstempel         Dein.Name
# 1 13.01.2023 10:09:51 A
# 2 13.01.2023 10:10:01 B
# 3 13.01.2023 10:12:26 C
# 4 13.01.2023 10:13:11 D
# 5 13.01.2023 10:14:10 E
# 6 13.01.2023 10:15:37 F
#   Erste.Schritte.mit.JavaScript..Der.Programmablauf..Umgang.mit.Fehlern.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 Kann ich im Ansatz
# 4 Kann ich im Ansatz
# 5 Kann ich im Ansatz
# 6 kann ich nicht
#   Erste.Schritte.mit.JavaScript..Variablen.in.JavaScript.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 Kann ich im Ansatz
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..Der..strict..Mode.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht
# 4 kann ich nicht
# 5 Kann ich im Ansatz
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..Verschiedene.Arten.von.Daten..Datentypen.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..Operatoren.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..Zeichenketten.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 Kann ich im Ansatz
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..Mathematische.Operationen.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht
# 4 Kann ich im Ansatz
# 5 Kann ich sicher
# 6 Kann ich sicher
#   Erste.Schritte.mit.JavaScript..String.zu.Zahl..Zahl.zu.String. ⋯
# 1 Kann ich sicher                                                ⋯
# 2 kann ich nicht                                                 ⋯
# 3 kann ich nicht                                                 ⋯
# 4 Kann ich im Ansatz                                             ⋯
# 5 Kann ich im Ansatz                                             ⋯
# 6 Kann ich im Ansatz                                             ⋯
#   Visual.Studio..Eine.NodeJS.Anwendung.debuggen.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht, Kann ich im Ansatz
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 kann ich nicht
#   Visual.Studio..NPM.in.Visual.Studio.nutzen.
# 1 Kann ich sicher
# 2 Kann ich im Ansatz
# 3 kann ich nicht, Kann ich im Ansatz
# 4 Kann ich sicher
# 5 Kann ich im Ansatz
# 6 kann ich nicht
#   Visual.Studio..Git.in.Visual.Studio.nutzen.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht, Kann ich im Ansatz
# 4 Kann ich im Ansatz
# 5 Kann ich sicher
# 6 kann ich nicht, Kann ich im Ansatz
#   Visual.Studio..Push.Kommando.in.ein.Github.Projekt.ausführen.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht, Kann ich im Ansatz
# 4 Kann ich im Ansatz
# 5 Kann ich sicher
# 6 kann ich nicht
#   Visual.Studio..Mittels.Pull.Kommando.lokale.Projekt.von..Github.aktualisieren.
# 1 Kann ich sicher
# 2 kann ich nicht
# 3 kann ich nicht, Kann ich im Ansatz
# 4 kann ich nicht
# 5 Kann ich sicher
# 6 kann ich nicht
#   Visual.Studio..launch.json.konfigurieren. Weiteres..Typescript.
# 1 kann ich nicht                            kann ich nicht
# 2 kann ich nicht                            kann ich nicht
# 3 kann ich nicht, Kann ich im Ansatz        kann ich nicht
# 4 Kann ich sicher                           Kann ich im Ansatz
# 5 Kann ich sicher                           kann ich nicht
# 6 kann ich nicht                            kann ich nicht
#   Weiteres..Frontend.Frameworks..VUE..Angular..React.. Weiteres..REST.
# 1 Kann ich im Ansatz                                   kann ich nicht
# 2 kann ich nicht                                       kann ich nicht
# 3 kann ich nicht                                       Kann ich im Ansatz
# 4 Kann ich im Ansatz                                   Kann ich sicher
# 5 Kann ich im Ansatz                                   kann ich nicht
# 6 kann ich nicht                                       kann ich nicht
#   Möchtest.Du.etwas.ergänzen.
# 1
# 2 Ist viel was ich noch nicht verstehe
# 3
# 4
# 5
# 6

# %%
#colnames(data)

colnames(data)[1]
# Out:
# [1] "Zeitstempel"

# %%
strsplit(colnames(data)[2]," ")
# Out:
# [[1]]
# [1] "Dein.Name"

# %% [markdown]
# # Clean Up Data

# %%
clean_colnames <- data %>%
    colnames() %>%
    sub("\\.\\."," - ",.) %>%
    gsub("\\."," ",.)


clean_colnames
# Out:
#   [1] "Zeitstempel"
#   [2] "Dein Name"
#   [3] "Erste Schritte mit JavaScript - Der Programmablauf  Umgang mit Fehlern "
#   [4] "Erste Schritte mit JavaScript - Variablen in JavaScript "
#   [5] "Erste Schritte mit JavaScript - Der  strict  Mode "
#   [6] "Erste Schritte mit JavaScript - Verschiedene Arten von Daten  Datentypen "
#   [7] "Erste Schritte mit JavaScript - Operatoren "
#   [8] "Erste Schritte mit JavaScript - Zeichenketten "
#   [9] "Erste Schritte mit JavaScript - Mathematische Operationen "
#  [10] "Erste Schritte mit JavaScript - String zu Zahl  Zahl zu String "
#  [11] "Erste Schritte mit JavaScript - Variablen erstellen  Const  var und let "
#  [12] "Erste Schritte mit JavaScript - Kommentare "
#  [13] "Listen verwalten - Arrays in JavaScript  Arrays in JavaScript "
#  [14] "Listen verwalten - Arrays in JavaScript  Veränderliche vs  Unveränderliche Variablen  mutable vs  immutable  "
#  [15] "Listen verwalten - Arrays in JavaScript  Typisierung   verschachteln von Arrays "
#  [16] "Listen verwalten - Arrays in JavaScript  String zu Array  Array zu String "
#  [17] "Kontrollstrukturen - Teil 1  if  else   Wahr Falsch Werte  Booleans  "
#  [18] "Kontrollstrukturen - Teil 1  if  else   If Abfragen "
#  [19] "Kontrollstrukturen - Teil 1  if  else   If   Else "
#  [20] "Kontrollstrukturen - Teil 1  if  else   Was bedeuten die geschweiften Klammern  "
#  [21] "Kontrollstrukturen - Teil 1  if  else   Else if "
#  [22] "Kontrollstrukturen - Teil 1  if  else   Operatoren für Booleans  So kannst du mit Wahr Falsch Werten rechnen "
#  [23] "Kontrollstrukturen - Teil 1  if  else   Expertenwissen  Reihenfolge der Operatoren "
#  [24] "Kontrollstrukturen - Teil 1  if  else   Was bedeutet if variable   "
#  [25] "Kontrollstrukturen - Teil 1  if  else   Vergleiche     vs      "
#  [26] "Kontrollstrukturen - Teil 1  if  else   Expertenwissen  optional   Randfälle  Spezifikation der Operatorenreihenfolge "
#  [27] "Kontrollstrukturen - Teil 2  Schleifen   While Schleife "
#  [28] "Kontrollstrukturen - Teil 2  Schleifen   for Schleife  Variante 1  "
#  [29] "Kontrollstrukturen - Teil 2  Schleifen   for Schleife  weitere Varianten  "
#  [30] "Kontrollstrukturen - Teil 2  Schleifen   Schleifen unterbrechen   abbrechen  continue und break "
#  [31] "Kontrollstrukturen - Teil 2  Schleifen   Expertenwissen  Debugging "
#  [32] "Funktionen - Funktionen "
#  [33] "Funktionen - Funktionsparameter "
#  [34] "Funktionen - Funktionsparameter  Was ist ein Standardparameter  "
#  [35] "Funktionen - Die Gültigkeit  scope  von Variablen  Teil 1  "
#  [36] "Funktionen - Rückgabewerte  return  "
#  [37] "Funktionen - Wichtig  Return beendet Funktion  "
#  [38] "Funktionen - Funktionen dokumentieren  Aufgabe "
#  [39] "Objekte in JavaScript - Objekt erstellen "
#  [40] "Objekte in JavaScript - Auf Eigenschaften zugreifen "
#  [41] "Objekte in JavaScript - Eigenschaften hinzufügen oder entfernen "
#  [42] "Objekte in JavaScript - Vorstellung  Die verschiedenen Schreibweisen "
#  [43] "Objekte in JavaScript - If Abfragen und Objekte "
#  [44] "Objekte in JavaScript - Schleifen und Object entries    Object keys   und Object values   "
#  [45] "Objekte in JavaScript - Autocompletion im Editor "
#  [46] "Objekte in JavaScript - Objekte verschachteln "
#  [47] "JSON - JavaScript Object Notation  Einführung  JSON  JavaScript Object Notation  "
#  [48] "JSON - JavaScript Object Notation  JSON einlesen "
#  [49] "JSON - JavaScript Object Notation  JSON ausgeben "
#  [50] "Funktionen - Anonyme Funktionen  Callbacks  Anonyme Funktionen "
#  [51] "Funktionen - Anonyme Funktionen  Callbacks  Warum brauchen wir anonyme Funktionen  "
#  [52] "Funktionen - Anonyme Funktionen  Callbacks  Anonyme Funktionen und NodeJS "
#  [53] "Funktionen - Anonyme Funktionen  Callbacks  Vorstellung  Kurzschreibweisen für Funktionen "
#  [54] "Funktionen - Anonyme Funktionen  Callbacks  Funktionen Beispiel  optional   Datei anfragen "
#  [55] "HTML und CSS - Die Baumstruktur von HTML "
#  [56] "HTML und CSS - HTML Tags verwenden "
#  [57] "HTML und CSS - Ein CSS Framework  z B Bootstrap  einbinden "
#  [58] "HTML und CSS - Eine Liste anlegen "
#  [59] "HTML und CSS - CSS Klassen erstellen "
#  [60] "HTML und CSS - Elemente Stylen via Tag "
#  [61] "HTML und CSS - Elemente stylen via Class "
#  [62] "HTML und CSS - Elemente stylen via ID "
#  [63] "HTML und CSS - Block  vs  Inline Elemente "
#  [64] "HTML und CSS - Das Box Modell "
#  [65] "HTML und CSS - Elemente per ID oder per Klasse ansteuern "
#  [66] "HTML und CSS - Span  und Div Elemente "
#  [67] "HTML und CSS - Komplexere Selektoren "
#  [68] "HTML und CSS - eine Seite Strukturieren  Header  Navigation  body  Footer  LeftSide  RightSide       "
#  [69] "JavaScript im Browser - JavaScript im Browser "
#  [70] "JavaScript im Browser - Crashkurs Webinspector "
#  [71] "JavaScript im Browser - JavaScript Datei aus HTML Datei laden "
#  [72] "JavaScript im Browser - Das Document Object Model "
#  [73] "JavaScript im Browser - Vorbereitung  Elemente finden "
#  [74] "JavaScript im Browser - Die Eigenschaften  innerText    innerHTML "
#  [75] "JavaScript im Browser - Warum du  innerText bevorzugen solltest "
#  [76] "JavaScript im Browser - Auf Ereignisse reagieren "
#  [77] "JavaScript im Browser - Auf Ereignisse reagieren  event preventDefault   "
#  [78] "JavaScript im Browser - Elemente finden  getElementsByClassName vs     TagName    "
#  [79] "JavaScript im Browser - Elemente finden  querySelector  querySelectorAll  "
#  [80] "JavaScript im Browser - Auf Attribute von Elementen zugreifen "
#  [81] "JavaScript im Browser - Projekt  Hilfe Hinweise entwickeln "
#  [82] "JavaScript im Browser - Klassen hinzufügen oder entfernen "
#  [83] "JavaScript im Browser - Auf Styles zugreifen "
#  [84] "JavaScript im Browser - Styles und die Auto Completion in Visual Studio Code "
#  [85] "JavaScript im Browser - Den Objektbaum  DOM  entlang navigieren "
#  [86] "JavaScript im Browser - Expertenwissen  Event Bubbling in JavaScript "
#  [87] "JavaScript im Browser - Elemente entfernen "
#  [88] "JavaScript im Browser - Elemente anhängen  appendChild  Teil 1  "
#  [89] "JavaScript im Browser - Elemente anhängen  appendChild  Teil 2  "
#  [90] "JavaScript im Browser - Die Befehle  before   after   prepend "
#  [91] "JavaScript im Browser - Auf eine Checkbox zugreifen "
#  [92] "JavaScript im Browser - Auf die Enter Taste reagieren "
#  [93] "JavaScript im Browser - Worauf du beim Hinzufügen von Elementen achten musst "
#  [94] "Objekte in JavaScript - Teil 2   Was bedeutet das this in JavaScript  "
#  [95] "Objekte in JavaScript - Teil 2   Warum brauchen wir das this überhaupt  "
#  [96] "Objekte in JavaScript - Teil 2   Exkurs  setTimeout   und setInterval   "
#  [97] "Objekte in JavaScript - Teil 2   Funktionstypen in JavaScript "
#  [98] "Objekte in JavaScript - Teil 2   Die Methoden  bind   und  apply   "
#  [99] "Objekte in JavaScript - Teil 2   Kürzere Schreibweise für Funktionen in Objekten "
# [100] "Der EventEmitter - Callback Funktionen setzen "
# [101] "Der EventEmitter - Eine Liste von Callback Funktionen "
# [102] "Der EventEmitter - Callback Funktion entgegen nehmen "
# [103] "Der EventEmitter - Callback registrieren "
# [104] "Der EventEmitter - EventEmitter abschließen "
# [105] "Der EventEmitter - EventEmitter im Browser  "
# [106] "Der EventEmitter - Kommentare hinzufügen "
# [107] "Der Prototyp in JavaScript - Objekt mit Object create   erstellen "
# [108] "Der Prototyp in JavaScript - Eigenschaft nachträglich hinzufügen  Object definePropety    "
# [109] "Der Prototyp in JavaScript - Wir setzen einen Prototypen "
# [110] "Der Prototyp in JavaScript - Prototyp manuell setzen "
# [111] "Der Prototyp in JavaScript - Die Prototypen Vererbung  Prototype Chain  "
# [112] "Der Prototyp in JavaScript - Die Prototypen Vererbung  Prototype Chain   Beispiel HTML Elemente "
# [113] "Der Prototyp in JavaScript - Prototypen   Constructor Funktion "
# [114] "Der Prototyp in JavaScript - Prototyp   Schleifen  hasOwnProperty "
# [115] "Code in mehreren Dateien - Module  Datei per require   einbinden "
# [116] "Code in mehreren Dateien - Module  Variablen exportieren  module exports  "
# [117] "Code in mehreren Dateien - Module  Mehrere Eigenschaften exportieren "
# [118] "Code in mehreren Dateien - Module  Paket einbinden "
# [119] "Code in mehreren Dateien - Module  Paketverwaltung mit NPM "
# [120] "Code in mehreren Dateien - Module  Sicherheit von Paketen "
# [121] "Code in mehreren Dateien - Module  Wie liest du die Versionsnummern  "
# [122] "Browser Setup - Babel "
# [123] "Browser Setup - Webpack "
# [124] "Browser Setup - JavaScript   ES6   Module ohne Webpack  "
# [125] "Asynchrones JavaScript - Asynchrones JavaScript  "
# [126] "Asynchrones JavaScript - Synchroner vs  Asynchroner Code "
# [127] "Asynchrones JavaScript - Warum brauchen wir asynchronen Code  "
# [128] "Asynchrones JavaScript -  Optional   Der Call Stack "
# [129] "Asynchrones JavaScript -  Optional   Wie funktioniert asynchrones JavaScript im Detail  "
# [130] "Asynchrones JavaScript - Promise "
# [131] "Asynchrones JavaScript - Promises und eine API "
# [132] "Error Handling - Error Handling  Try und Catch "
# [133] "Error Handling - Error Handling in NodeJS "
# [134] "Error Handling - Error Handling   Promises "
# [135] "Error Handling - Eigene Fehler werfen "
# [136] "Moderne JavaScript Features - Template Strings "
# [137] "Moderne JavaScript Features -  Optional   Tagged Template Strings "
# [138] "Moderne JavaScript Features - Objekte entpacken "
# [139] "Moderne JavaScript Features - Listen packen und entpacken "
# [140] "Moderne JavaScript Features - Elemente transformieren  Array map   "
# [141] "Moderne JavaScript Features - Arrays filtern  Array filter   "
# [142] "Moderne JavaScript Features - Callback Funktion für jedes Element aufrufen  Array forEach   "
# [143] "Moderne JavaScript Features - Elemente suchen  Array find    Array findIndex   "
# [144] "Moderne JavaScript Features - Prüfen ob ein Element in einem Array vorhanden ist  Array some   "
# [145] "Moderne JavaScript Features - Komplexe Berechnungen mit Array reduce   "
# [146] "NodeJS - Ein einfacher Server mit NodeJS  http createServer    "
# [147] "NodeJS - Wir untersuchen den Parameter res  Antwort  genauer "
# [148] "NodeJS - Antwort Header verschicken "
# [149] "NodeJS - Anfrage verarbeiten "
# [150] "NodeJS - Dateien mit NodeJS ausliefern "
# [151] "NodeJS - Statische Dateien ausliefern  URL besser einlesen "
# [152] "NodeJS - Objekt als JSON ausliefern für eine API "
# [153] "NodeJS - HTTP Methoden "
# [154] "NodeJS - Ein Formular erstellen und auswerten "
# [155] "Express - Einen Server aufsetzen "
# [156] "Express - Routing "
# [157] "Express - Middleware nutzen "
# [158] "Express - Middleware erstellen "
# [159] "Express - Projektstruktur "
# [160] "Express - Template Engines "
# [161] "Git -  Github  Ein Projekt lokal initiieren "
# [162] "Git -  Github  die git cli nutzen "
# [163] "Git -  Github  In ein Projekt commiten "
# [164] "Git -  Github  Ein Projekt auf Github veröffentlichen "
# [165] "Git -  Github  Ein Github Projekt lokal clonen "
# [166] "NPM - Ein NPM Projekt initiieren "
# [167] "NPM - Ein NPM Projekt starten "
# [168] "NPM - NPM CLI nutzen "
# [169] "NPM - Pakete installieren "
# [170] "NPM - Installierte Pakete anzeigen lassen "
# [171] "Visual Studio - ein neues Projekt anlegen "
# [172] "Visual Studio - HTML Code erstellen "
# [173] "Visual Studio - CSS Code erstellen "
# [174] "Visual Studio - JavaScript Code erstellen "
# [175] "Visual Studio - Eine JavaScript Anwendung im Browser debuggen "
# [176] "Visual Studio - Eine NodeJS Anwendung debuggen "
# [177] "Visual Studio - NPM in Visual Studio nutzen "
# [178] "Visual Studio - Git in Visual Studio nutzen "
# [179] "Visual Studio - Push Kommando in ein Github Projekt ausführen "
# [180] "Visual Studio - Mittels Pull Kommando lokale Projekt von  Github aktualisieren "
# [181] "Visual Studio - launch json konfigurieren "
# [182] "Weiteres - Typescript "
# [183] "Weiteres - Frontend Frameworks  VUE  Angular  React  "
# [184] "Weiteres - REST "
# [185] "Möchtest Du etwas ergänzen "

# %% [markdown]
# # pivot data for analysis

# %%
#colnames(data)

# %%
data_pivot <- data %>% 
    select(-Zeitstempel, -Möchtest.Du.etwas.ergänzen.) %>% 
    gather(Variable, Antwort, -Dein.Name)

# %%
data_pivot$Variable <- sub("\\.\\."," - ",data_pivot$Variable)
data_pivot$Variable <- gsub("\\."," ",data_pivot$Variable)

# %%
data_pivot_groups <- data_pivot %>% separate(Variable, c("Gruppe", "Thema"), sep="-")

# %% [markdown]
# # Now let's get actual values to work with:
# - convert responses to categorical variables or numeric

# %%
levels(as.factor(data_pivot_groups$Antwort))
# Out:
# [1] ""
# [2] "Kann ich im Ansatz"
# [3] "Kann ich im Ansatz, Kann ich sicher"
# [4] "Kann ich sicher"
# [5] "kann ich nicht"
# [6] "kann ich nicht, Kann ich im Ansatz"
# [7] "kann ich nicht, Kann ich im Ansatz, Kann ich sicher"
# [8] "kann ich nicht, Kann ich sicher"

# %%
unique(data_pivot_groups$Gruppe)
# Out:
#  [1] "Erste Schritte mit JavaScript " "Listen verwalten "
#  [3] "Kontrollstrukturen "            "Funktionen "
#  [5] "Objekte in JavaScript "         "JSON "
#  [7] "HTML und CSS "                  "JavaScript im Browser "
#  [9] "Der EventEmitter "              "Der Prototyp in JavaScript "
# [11] "Code in mehreren Dateien "      "Browser Setup "
# [13] "Asynchrones JavaScript "        "Error Handling "
# [15] "Moderne JavaScript Features "   "NodeJS "
# [17] "Express "                       "Git "
# [19] "NPM "                           "Visual Studio "
# [21] "Weiteres "

# %%
data_num <- data_pivot_groups %>% 
    mutate(txt_Antwort = Antwort) %>%
    # check if checked all options:
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich im Ansatz, Kann ich sicher', 'NA')) %>%
    # check if checked 2:
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich im Ansatz', '1')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich im Ansatz, Kann ich sicher', '3')) %>%
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich sicher', 'NA')) %>%
    # check single choices:
    mutate(across('Antwort', str_replace, 'kann ich nicht', '0')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich im Ansatz', '2')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich sicher', '4')) %>%
    mutate(num_Antwort = as.numeric(Antwort), 
           Gruppe = factor(Gruppe, levels=rev(unique(Gruppe))), 
           Thema = factor(Thema, levels=unique(Thema)),
          Name = factor(Dein.Name, levels=rev(unique(Dein.Name)))) %>%
    select(-Antwort, -Dein.Name)

data_num_norev <- data_pivot_groups %>% 
    mutate(txt_Antwort = Antwort) %>%
    # check if checked all options:
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich im Ansatz, Kann ich sicher', 'NA')) %>%
    # check if checked 2:
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich im Ansatz', '1')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich im Ansatz, Kann ich sicher', '3')) %>%
    mutate(across('Antwort', str_replace, 'kann ich nicht, Kann ich sicher', 'NA')) %>%
    # check single choices:
    mutate(across('Antwort', str_replace, 'kann ich nicht', '0')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich im Ansatz', '2')) %>%
    mutate(across('Antwort', str_replace, 'Kann ich sicher', '4')) %>%
    mutate(num_Antwort = as.numeric(Antwort), 
           Gruppe = factor(Gruppe, levels=unique(Gruppe)), 
           Thema = factor(Thema, levels=unique(Thema)),
          Name = factor(Dein.Name, levels=unique(Dein.Name))) %>%
    select(-Antwort, -Dein.Name)
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs durch Umwandlung erzeugt”
# Warning message in mask$eval_all_mutate(quo):
# “NAs durch Umwandlung erzeugt”

# %%
head(data_num)
# Out:
#   Gruppe                         Thema
# 1 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
# 2 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
# 3 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
# 4 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
# 5 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
# 6 Erste Schritte mit JavaScript   Der Programmablauf  Umgang mit Fehlern
#   txt_Antwort        num_Antwort Name
# 1 Kann ich sicher    4           A
# 2 kann ich nicht     0           B
# 3 Kann ich im Ansatz 2           C
# 4 Kann ich im Ansatz 2           D
# 5 Kann ich im Ansatz 2           E
# 6 kann ich nicht     0           F

# %% [markdown]
# # Finally we can start analysing!
#
# ## First let us look at the outliers and raw data

# %%
levels(data_num$Gruppe)
# Out:
#  [1] "Weiteres "                      "Visual Studio "
#  [3] "NPM "                           "Git "
#  [5] "Express "                       "NodeJS "
#  [7] "Moderne JavaScript Features "   "Error Handling "
#  [9] "Asynchrones JavaScript "        "Browser Setup "
# [11] "Code in mehreren Dateien "      "Der Prototyp in JavaScript "
# [13] "Der EventEmitter "              "JavaScript im Browser "
# [15] "HTML und CSS "                  "JSON "
# [17] "Objekte in JavaScript "         "Funktionen "
# [19] "Kontrollstrukturen "            "Listen verwalten "
# [21] "Erste Schritte mit JavaScript "

# %%
# first lets try and plot the raw data
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    mutate(answer = as.factor(num_Antwort)) %>% 
    ggplot(aes(x = Gruppe)) +
    geom_bar(aes(fill = answer), position = "fill") -> p1
p1 + coord_flip() + theme_cowplot() + ggtitle("Antworten pro Themengruppe")
ggsave("01_ApT1.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
# first lets try and plot the raw data
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    mutate(answer = as.factor(num_Antwort)) %>% 
    ggplot(aes(x = Name)) +
    geom_bar(aes(fill = answer), position = "fill") -> p1
p1 + coord_flip() + theme_cowplot() + ggtitle("Antworten pro Person")
ggsave("02_ApP1.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
data_num_norev %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
group_by(Name) %>%
    summarise(Name = Name, Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%

    ggplot(aes(x = Name, y = Mean)) +
    geom_point(color="red", size=5) +
    geom_errorbar(aes(ymin=pmax(Mean-SD,0), ymax=Mean+SD), width=.1,
                 position=position_dodge(0.05)) -> p1
    #geom_bar(aes(fill = answer), position = "fill") -> p1
p1  + theme_cowplot() + ggtitle("Mittelwert Antworten pro Person") #+ ylim(0,4)
ggsave("03_meanApP1.pdf")
# Out:
# `summarise()` has grouped output by 'Name'. You can override using the `.groups` argument.
# Saving 7 x 7 in image
# plot without title

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
group_by(Gruppe) %>%
    summarise(Gruppe = Gruppe, Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%

    ggplot(aes(x = Gruppe, y = Mean)) +
    geom_point(color="red", size=5) +
    geom_errorbar(aes(ymin=pmax(Mean-SD,0), ymax=Mean+SD), width=.1,
                 position=position_dodge(0.05)) -> p1
    #geom_bar(aes(fill = answer), position = "fill") -> p1
p1 + coord_flip() + theme_cowplot() + ggtitle("Mittelwert Antworten pro Thema") #+ ylim(0,4)
ggsave("04_meanApT1.pdf")
# Out:
# `summarise()` has grouped output by 'Gruppe'. You can override using the `.groups` argument.
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# # Themengruppe nach Mittelwert Antwort

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Gruppe) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%
    arrange(desc(Mean))
# Out:
#    Gruppe                         Mean      SD
# 1  Visual Studio                  2.6315789 1.4978054
# 2  Git                            2.4680851 1.4569236
# 3  Erste Schritte mit JavaScript  2.4623656 1.5976952
# 4  HTML und CSS                   2.3650190 1.5043933
# 5  NPM                            2.1348315 1.5896756
# 6  Kontrollstrukturen             2.0318021 1.5167081
# 7  JSON                           1.9473684 1.5745867
# 8  Funktionen                     1.5330396 1.3608011
# 9  Code in mehreren Dateien       1.4523810 1.3600420
# 10 JavaScript im Browser          1.4211663 1.4225096
# 11 Listen verwalten               1.4027778 1.1464547
# 12 Objekte in JavaScript          1.3384030 1.2794353
# 13 NodeJS                         1.0760234 1.2461982
# 14 Express                        0.9912281 1.2515167
# 15 Der Prototyp in JavaScript     0.6323529 0.9334034
# 16 Moderne JavaScript Features    0.6210526 0.9163875
# 17 Asynchrones JavaScript         0.5227273 0.9920748
# 18 Der EventEmitter               0.5187970 1.0120599
# 19 Weiteres                       0.4561404 1.0012523
# 20 Browser Setup                  0.4561404 1.2545656
# 21 Error Handling                 0.3684211 0.7804632

# %% [markdown]
# ## Themengruppe nach SD

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Gruppe) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%
    arrange(desc(SD))
# Out:
#    Gruppe                         Mean      SD
# 1  Erste Schritte mit JavaScript  2.4623656 1.5976952
# 2  NPM                            2.1348315 1.5896756
# 3  JSON                           1.9473684 1.5745867
# 4  Kontrollstrukturen             2.0318021 1.5167081
# 5  HTML und CSS                   2.3650190 1.5043933
# 6  Visual Studio                  2.6315789 1.4978054
# 7  Git                            2.4680851 1.4569236
# 8  JavaScript im Browser          1.4211663 1.4225096
# 9  Funktionen                     1.5330396 1.3608011
# 10 Code in mehreren Dateien       1.4523810 1.3600420
# 11 Objekte in JavaScript          1.3384030 1.2794353
# 12 Browser Setup                  0.4561404 1.2545656
# 13 Express                        0.9912281 1.2515167
# 14 NodeJS                         1.0760234 1.2461982
# 15 Listen verwalten               1.4027778 1.1464547
# 16 Der EventEmitter               0.5187970 1.0120599
# 17 Weiteres                       0.4561404 1.0012523
# 18 Asynchrones JavaScript         0.5227273 0.9920748
# 19 Der Prototyp in JavaScript     0.6323529 0.9334034
# 20 Moderne JavaScript Features    0.6210526 0.9163875
# 21 Error Handling                 0.3684211 0.7804632

# %% [markdown]
# # Thema nach Mittelwert Antwort

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Thema) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%
    arrange(desc(Mean))
# Out:
#     Thema
# 1    ein neues Projekt anlegen
# 2    HTML Code erstellen
# 3    CSS Code erstellen
# 4    Die Baumstruktur von HTML
# 5    CSS Klassen erstellen
# 6    JavaScript Code erstellen
# 7    Teil 1  if  else   Was bedeuten die geschweiften Klammern
# 8    HTML Tags verwenden
# 9    eine Seite Strukturieren  Header  Navigation  body  Footer  LeftSide  RightSide
# 10   Kommentare
# 11   Zeichenketten
# 12   Elemente stylen via Class
# 13   Ein CSS Framework  z B Bootstrap  einbinden
# 14    Github  Ein Github Projekt lokal clonen
# 15   Variablen in JavaScript
# 16   Teil 1  if  else   Was bedeutet if variable
# 17   Verschiedene Arten von Daten  Datentypen
# 18   Variablen erstellen  Const  var und let
# 19   Teil 1  if  else   Else if
# 20   Funktionen
# 21    Github  In ein Projekt commiten
# 22   Git in Visual Studio nutzen
# 23   Mathematische Operationen
# 24   Elemente Stylen via Tag
# 25   JavaScript im Browser
# 26   Operatoren
# 27   Teil 1  if  else   If Abfragen
# 28   Eine Liste anlegen
# 29    Github  Ein Projekt auf Github veröffentlichen
# 30   Teil 1  if  else   Wahr Falsch Werte  Booleans
# ⋮   ⋮
# 153  Asynchrones JavaScript
# 154  Objekt als JSON ausliefern für eine API
# 155  Die Befehle  before   after   prepend
# 156  Die Prototypen Vererbung  Prototype Chain   Beispiel HTML Elemente
# 157  JavaScript   ES6   Module ohne Webpack
# 158   Optional   Der Call Stack
# 159  Error Handling  Try und Catch
# 160  Eigene Fehler werfen
# 161  Arrays filtern  Array filter
# 162  Typescript
# 163  Expertenwissen  Event Bubbling in JavaScript
# 164  Teil 1  if  else   Expertenwissen  optional   Randfälle  Spezifikation der Operatorenreihenfolge
# 165  Eine Liste von Callback Funktionen
# 166   Optional   Tagged Template Strings
# 167  Babel
# 168  Webpack
# 169   Optional   Wie funktioniert asynchrones JavaScript im Detail
# 170  Prüfen ob ein Element in einem Array vorhanden ist  Array some
# 171  Frontend Frameworks  VUE  Angular  React
# 172  REST
# 173  Eigenschaft nachträglich hinzufügen  Object definePropety
# 174  Callback registrieren
# 175  Promises und eine API
# 176  Error Handling in NodeJS
# 177  Prototyp   Schleifen  hasOwnProperty
# 178  Promise
# 179  Komplexe Berechnungen mit Array reduce
# 180  EventEmitter abschließen
# 181  EventEmitter im Browser
# 182  Error Handling   Promises
#     Mean      SD
# 1   3.578947  0.8377078
# 2   3.526316  0.8411910
# 3   3.526316  0.8411910
# 4   3.111111  1.0786096
# 5   3.105263  1.1969747
# 6   3.105263  1.1969747
# 7   3.000000  1.4529663
# 8   2.947368  1.0259784
# 9   2.894737  1.1969747
# 10  2.888889  1.7111705
# 11  2.842105  1.3849652
# 12  2.833333  1.3826658
# 13  2.736842  1.3679711
# 14  2.736842  1.4079972
# 15  2.684211  1.6347827
# 16  2.684211  1.5653410
# 17  2.631579  1.4985373
# 18  2.631579  1.4985373
# 19  2.631579  1.4609938
# 20  2.631579  1.2115429
# 21  2.631579  1.3828524
# 22  2.631579  1.4609938
# 23  2.588235  1.6977494
# 24  2.578947  1.4649911
# 25  2.578947  1.3045131
# 26  2.526316  1.4669856
# 27  2.526316  1.3485968
# 28  2.526316  1.4669856
# 29  2.526316  1.5043796
# 30  2.500000  1.6179144
# ⋮   ⋮         ⋮
# 153 0.5789474 1.1212983
# 154 0.5789474 0.8377078
# 155 0.5555556 0.8555853
# 156 0.5294118 0.8744746
# 157 0.5263158 1.3067526
# 158 0.5263158 1.0733344
# 159 0.5263158 0.9048279
# 160 0.5263158 0.9048279
# 161 0.5263158 0.8411910
# 162 0.5263158 1.1239030
# 163 0.5000000 1.0981267
# 164 0.4736842 0.8411910
# 165 0.4736842 1.0202626
# 166 0.4736842 0.8411910
# 167 0.4210526 1.2612071
# 168 0.4210526 1.2612071
# 169 0.4210526 0.8377078
# 170 0.4210526 0.7685332
# 171 0.4210526 0.8377078
# 172 0.4210526 1.0706068
# 173 0.4117647 0.7952062
# 174 0.3157895 0.6710383
# 175 0.3157895 0.7492686
# 176 0.3157895 0.7492686
# 177 0.2941176 0.6859943
# 178 0.2222222 0.6467617
# 179 0.2105263 0.5353034
# 180 0.1578947 0.5014599
# 181 0.1578947 0.5014599
# 182 0.1052632 0.4588315

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Thema) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%
    #arrange(desc(Mean)) %>%
ggplot(aes(x=Thema,y=Mean))+geom_point() + coord_flip()+ theme_minimal_grid(font_size=5)
# Out:
# plot without title

# %% [markdown]
# ## Thema nach SD

# %%
data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Thema) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE), SD = sd(num_Antwort, na.rm=TRUE)) %>%
    arrange(desc(SD))

# %%
# Let's try generating a word cloud
library(wordcloud)
# Out:
# Lade nötiges Paket: RColorBrewer

# %%
meanthema <- data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Thema) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE))
head(meanthema)
# Out:
#   Thema                                      Mean
# 1  Der Programmablauf  Umgang mit Fehlern    2.105263
# 2  Variablen in JavaScript                   2.684211
# 3  Der  strict  Mode                         1.421053
# 4  Verschiedene Arten von Daten  Datentypen  2.631579
# 5  Operatoren                                2.526316
# 6  Zeichenketten                             2.842105

# %%
options(repr.plot.width=10, repr.plot.height=10)

set.seed(1234)
wordcloud(words = meanthema$Thema, freq = 10**meanthema$Mean, min.freq = 0.5,           
          max.words=200, random.order=FALSE, rot.per=0.35,            
          colors=brewer.pal(5, "RdYlGn"), scale=c(3, .2))
# Out:
# plot without title

# %%
brewer.pal(8, "Dark2")
# Out:
# [1] "#1B9E77" "#D95F02" "#7570B3" "#E7298A" "#66A61E" "#E6AB02" "#A6761D"
# [8] "#666666"

# %%
options(repr.plot.width=10, repr.plot.height=10)

set.seed(1234)
wordcloud(words = meanthema$Thema, freq = 10**abs(meanthema$Mean-5), min.freq = 1.5,           
          max.words=200, random.order=FALSE, rot.per=0.35,            
          colors=brewer.pal(8, "YlOrRd"), scale=c(2., .1))
# Out:
# plot without title

# %%
meangruppe <- data_num %>%
    select(Gruppe, Thema, num_Antwort, Name) %>%
    #mutate(answer = as.factor(num_Antwort)) %>% 
    group_by(Gruppe) %>%
    summarise(Mean = mean(num_Antwort, na.rm=TRUE))
head(meangruppe)
# Out:
#   Gruppe         Mean
# 1 Weiteres       0.4561404
# 2 Visual Studio  2.6315789
# 3 NPM            2.1348315
# 4 Git            2.4680851
# 5 Express        0.9912281
# 6 NodeJS         1.0760234

# %%
pdf("mywordcloud.pdf")
options(repr.plot.width=8, repr.plot.height=8)

set.seed(1234)
negatiivGruppe_WC <- wordcloud(words = meangruppe$Gruppe, freq = 10**abs(meangruppe$Mean-5), min.freq = 0,           
          max.words=20, random.order=FALSE, rot.per=0.35,            
          colors=brewer.pal(8, "YlOrRd"), scale=c(4, .3)) 
negatiivGruppe_WC
dev.off()
# Out:
# NULL
# pdf
#   2

# %%
abs(1-5)
# Out:
# [1] 4

# %%
abs(1-5)
